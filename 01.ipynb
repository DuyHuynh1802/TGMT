# %%
from PIL import Image

# %%
dir = 'C:/Users/philo/Desktop/Picture'

# %%
image_path = dir +'/1.JPG'
print(image_path)
# Out:
# C:/Users/philo/Desktop/Picture/1.JPG

# %%
img = Image.open(image_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=599x399>

# %%
print("Định dạng ảnh: ", img.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img.size)
# Out:
# Kích thước hình ảnh:  (599, 399)

# %%
new_img_path = dir + '/new_01.JPG'
new_img_png_path = dir + '/new_01.PNG'
img.save(new_img_path)
img.save(new_img_png_path)

# %%
img.close()
