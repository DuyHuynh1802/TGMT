# %%
from PIL import Image
from imgtools import *

# %%
my_dir = 'C:/Users/philo/Desktop/Picture'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (599, 399)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=599x399>
# (608, 457)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=608x457>
# (736, 597)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x597>
# (626, 358)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x358>
# (599, 399)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=599x399>
# (599, 399)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=599x399>
