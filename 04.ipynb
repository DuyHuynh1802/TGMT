# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/philo/Desktop/Picture/1.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=599x399>

# %%
region = (100, 100, 280, 330)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=180x230>

# %%
paste_position = (400, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=599x399>
